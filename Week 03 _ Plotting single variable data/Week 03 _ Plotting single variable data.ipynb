# %%
import pandas as pd
pd.set_option('display.float_format', '{:.2f}'.format)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import linregress

# %%
tips = sns.load_dataset("tips")
sns.stripplot(x="day", y="total_bill", data=tips, jitter=True);

# %%
tips = sns.load_dataset("tips")

# Create a dot plot of total_bill values
plt.plot(tips["total_bill"], [0] * len(tips), ".", markersize=10)

# Set the plot title and x-axis label
plt.title("Dot Plot of Total Bill")
plt.xlabel("Total Bill")
# Out:
# Text(0.5, 0, 'Total Bill')

# %%
sns.stripplot(x='total_bill', data=tips, jitter=True)
# Out:
# <AxesSubplot:xlabel='total_bill'>
