# %% [markdown]
# <center> <h1>DS & ML Final Test</h1> </center>

# %% [markdown]
# **NAME**: Mishbah

# %% [markdown]
# **Note:** Run all cells and save your test notebook with name "**𝗗𝗦&𝗠𝗟 Hybird 04**_𝗬𝗼𝘂𝗿_𝗡𝗮𝗺𝗲_𝗵𝗲𝗿𝗲.𝗶𝗽𝘆𝗻𝗯" then submit it on below mentioned google form link.

# %% [markdown]
# <img src='https://i.pinimg.com/originals/28/6c/e0/286ce0190a188a8958bd81b5420eb09d.gif'>

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# Import necessary libraries

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 500)

# %% [markdown]
# Reading Dataset from csv

# %%
df_w=pd.read_csv('wrangling.csv')
df_w.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
#    height  curb-weight engine-type num-of-cylinders  engine-size fuel-system  \
# 0    48.8         2548        dohc             four          130        mpfi
# 1    48.8         2548        dohc             four          130        mpfi
# 2    52.4         2823        ohcv              six          152        mpfi
# 3    54.3         2337         ohc             four          109        mpfi
# 4    54.3         2824         ohc             five          136        mpfi
#
#    bore stroke  compression-ratio horsepower peak-rpm  city-mpg  highway-mpg  \
# 0  3.47   2.68                9.0        111     5000        21           27
# 1  3.47   2.68                9.0        111     5000        21           27
# 2  2.68   3.47                9.0        154     5000        19           26
# 3  3.19   3.40               10.0        102     5500        24           30
# 4  3.19   3.40                8.0        115     5500        18           22
#
#    price
# 0  13495
# 1  16500
# 2  16500
# 3  13950
# 4  17450

# %%
df_w
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0            two  convertible          rwd           front        88.6
# 1            two  convertible          rwd           front        88.6
# 2            two    hatchback          rwd           front        94.5
# 3           four        sedan          fwd           front        99.8
# 4           four        sedan          4wd           front        99.4
# ..           ...          ...          ...             ...         ...
# 200         four        sedan          rwd           front       109.1
# 201         four        sedan          rwd           front       109.1
# 202         four        sedan          rwd           front       109.1
# 203         four        sedan          rwd           front       109.1
# 204         four        sedan          rwd           front       109.1
#
#      length  width  height  curb-weight engine-type num-of-cylinders  \
# 0     168.8   64.1    48.8         2548        dohc             four
# 1     168.8   64.1    48.8         2548        dohc             four
# 2     171.2   65.5    52.4         2823        ohcv              six
# 3     176.6   66.2    54.3         2337         ohc             four
# 4     176.6   66.4    54.3         2824         ohc             five
# ..      ...    ...     ...          ...         ...              ...
# 200   188.8   68.9    55.5         2952         ohc             four
# 201   188.8   68.8    55.5         3049         ohc             four
# 202   188.8   68.9    55.5         3012        ohcv              six
# 203   188.8   68.9    55.5         3217         ohc              six
# 204   188.8   68.9    55.5         3062         ohc             four
#
#      engine-size fuel-system  bore stroke  compression-ratio horsepower  \
# 0            130        mpfi  3.47   2.68                9.0        111
# 1            130        mpfi  3.47   2.68                9.0        111
# 2            152        mpfi  2.68   3.47                9.0        154
# 3            109        mpfi  3.19   3.40               10.0        102
# 4            136        mpfi  3.19   3.40                8.0        115
# ..           ...         ...   ...    ...                ...        ...
# 200          141        mpfi  3.78   3.15                9.5        114
# 201          141        mpfi  3.78   3.15                8.7        160
# 202          173        mpfi  3.58   2.87                8.8        134
# 203          145         idi  3.01   3.40               23.0        106
# 204          141        mpfi  3.78   3.15                9.5        114
#
#     peak-rpm  city-mpg  highway-mpg  price
# 0       5000        21           27  13495
# 1       5000        21           27  16500
# 2       5000        19           26  16500
# 3       5500        24           30  13950
# 4       5500        18           22  17450
# ..       ...       ...          ...    ...
# 200     5400        23           28  16845
# 201     5300        19           25  19045
# 202     5500        18           23  21485
# 203     4800        26           27  22470
# 204     5400        19           25  22625
#
# [205 rows x 26 columns]

# %%
df_w.describe(include=['object'])
# Out:
#        normalized-losses    make fuel-type aspiration num-of-doors body-style  \
# count                205     205       205        205          205        205
# unique                52      22         2          2            3          5
# top                    ?  toyota       gas        std         four      sedan
# freq                  41      32       185        168          114         96
#
#        drive-wheels engine-location engine-type num-of-cylinders fuel-system  \
# count           205             205         205              205         205
# unique            3               2           7                7           8
# top             fwd           front         ohc             four        mpfi
# freq            120             202         148              159          94
#
#         bore stroke horsepower peak-rpm price
# count    205    205        205      205   205
# unique    39     37         60       24   187
# top     3.62   3.40         68     5500     ?
# freq      23     20         19       37     4

# %% [markdown]
# ### Section 1: Identify erroneous data and figuring out missing values

# %% [markdown]
# *Hint: Make sure to replace "?" with np.Nan first*

# %%
#write code here
df_w.replace('?', np.nan, inplace=True)

# %%
#write code here
df_w.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
#    height  curb-weight engine-type num-of-cylinders  engine-size fuel-system  \
# 0    48.8         2548        dohc             four          130        mpfi
# 1    48.8         2548        dohc             four          130        mpfi
# 2    52.4         2823        ohcv              six          152        mpfi
# 3    54.3         2337         ohc             four          109        mpfi
# 4    54.3         2824         ohc             five          136        mpfi
#
#    bore stroke  compression-ratio horsepower peak-rpm  city-mpg  highway-mpg  \
# 0  3.47   2.68                9.0        111     5000        21           27
# 1  3.47   2.68                9.0        111     5000        21           27
# 2  2.68   3.47                9.0        154     5000        19           26
# 3  3.19   3.40               10.0        102     5500        24           30
# 4  3.19   3.40                8.0        115     5500        18           22
#
#    price
# 0  13495
# 1  16500
# 2  16500
# 3  13950
# 4  17450

# %% [markdown]
# ### Section 2: Deal with missing data

# %%
#write code here
df_w.isna().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
#write code here
df_w.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
#write code here
df_w.bore.astype(float).mean()
# Out:
# 3.3297512437810957

# %%
#write code here
df_w.stroke.astype(float).mean()
# Out:
# 3.2554228855721337

# %%
#write code here
df=df_w.copy()

# %%
df['bore'] = df.bore.astype(float)
df['stroke'] = df.stroke.astype(float)

# %%
df[ ((df['engine-type']=='ohc') | (df['engine-type']=='ohcf')) & 
   ((df['bore']>3.35) & ((df['bore']<3.60)) & 
    (df['fuel-system']== 'mpfi' )  )&
  ((df['stroke']<3.1))].shape
# Out:
# (5, 26)

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df.stroke.mean()
# Out:
# 3.2554228855721337

# %%
df['num-of-doors'].value_counts()
# Out:
# four    114
# two      89
# Name: num-of-doors, dtype: int64

# %% [markdown]
# # EDA

# %% [markdown]
#  Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
#  load data and store in dataframe df_e:

# %%
data_e = pd.read_csv('eda.csv')
df_e=data_e.copy()

# %%
df= data_e.copy()

# %%
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length     width  \
# 0  convertible          rwd           front        88.6  0.811148  0.890278
# 1  convertible          rwd           front        88.6  0.811148  0.890278
# 2    hatchback          rwd           front        94.5  0.822681  0.909722
# 3        sedan          fwd           front        99.8  0.848630  0.919444
# 4        sedan          4wd           front        99.4  0.848630  0.922222
#
#    height  curb-weight engine-type num-of-cylinders  engine-size fuel-system  \
# 0    48.8         2548        dohc             four          130        mpfi
# 1    48.8         2548        dohc             four          130        mpfi
# 2    52.4         2823        ohcv              six          152        mpfi
# 3    54.3         2337         ohc             four          109        mpfi
# 4    54.3         2824         ohc             five          136        mpfi
#
#    bore  stroke  compression-ratio  horsepower  peak-rpm  city-mpg  \
# 0  3.47    2.68                9.0       111.0    5000.0        21
# 1  3.47    2.68                9.0       111.0    5000.0        21
# 2  2.68    3.47                9.0       154.0    5000.0        19
# 3  3.19    3.40               10.0       102.0    5500.0        24
# 4  3.19    3.40                8.0       115.0    5500.0        18
#
#    highway-mpg  price  city-L/100km horsepower-binned  diesel  gas
# 0           27  13495     11.190476            Medium       0    1
# 1           27  16500     11.190476            Medium       0    1
# 2           26  16500     12.368421            Medium       0    1
# 3           30  13950      9.791667            Medium       0    1
# 4           22  17450     13.055556            Medium       0    1

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                  int64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object

# %%
import seaborn as sns
plt.figure()
plt.title(' correlation between "price" and "engine-size".', fontsize=14)
sns.scatterplot(x='price', y='engine-size', data=df);

# %%
df['price'].corr(df['engine-size'])
# Out:
# 0.8723351674455196

# %%
df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015    0.837102    0.915126
# std      1.254802           31.99625    6.066366    0.059213    0.029187
# min     -2.000000           65.00000   86.600000    0.678039    0.837500
# 25%      0.000000          101.00000   94.500000    0.801538    0.890278
# 50%      1.000000          122.00000   97.000000    0.832292    0.909722
# 75%      2.000000          137.00000  102.400000    0.881788    0.925000
# max      3.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  197.000000
# mean    53.766667  2555.666667   126.875622    3.330692    3.256904
# std      2.447822   517.296727    41.546834    0.268072    0.319256
# min     47.800000  1488.000000    61.000000    2.540000    2.070000
# 25%     52.000000  2169.000000    98.000000    3.150000    3.110000
# 50%     54.100000  2414.000000   120.000000    3.310000    3.290000
# 75%     55.500000  2926.000000   141.000000    3.580000    3.410000
# max     59.800000  4066.000000   326.000000    3.940000    4.170000
#
#        compression-ratio  horsepower     peak-rpm    city-mpg  highway-mpg  \
# count         201.000000  201.000000   201.000000  201.000000   201.000000
# mean           10.164279  103.405534  5117.665368   25.179104    30.686567
# std             4.004965   37.365700   478.113805    6.423220     6.815150
# min             7.000000   48.000000  4150.000000   13.000000    16.000000
# 25%             8.600000   70.000000  4800.000000   19.000000    25.000000
# 50%             9.000000   95.000000  5125.369458   24.000000    30.000000
# 75%             9.400000  116.000000  5500.000000   30.000000    34.000000
# max            23.000000  262.000000  6600.000000   49.000000    54.000000
#
#               price  city-L/100km      diesel         gas
# count    201.000000    201.000000  201.000000  201.000000
# mean   13207.129353      9.944145    0.099502    0.900498
# std     7947.066342      2.534599    0.300083    0.300083
# min     5118.000000      4.795918    0.000000    0.000000
# 25%     7775.000000      7.833333    0.000000    1.000000
# 50%    10295.000000      9.791667    0.000000    1.000000
# 75%    16500.000000     12.368421    0.000000    1.000000
# max    45400.000000     18.076923    1.000000    1.000000

# %%
df.groupby('drive-wheels')['price'].mean()
# Out:
# drive-wheels
# 4wd    10241.000000
# fwd     9244.779661
# rwd    19757.613333
# Name: price, dtype: float64

# %%
df.groupby('drive-wheels')['price'].max()
# Out:
# drive-wheels
# 4wd    17450
# fwd    23875
# rwd    45400
# Name: price, dtype: int64

# %%
sns.set(style="white")

fig = plt.figure(figsize=(8,4))

sns.boxplot(x='body-style', y='price', data=df);

# %%
df.head(50)
# Out:
#     symboling  normalized-losses         make aspiration num-of-doors  \
# 0           3                122  alfa-romero        std          two
# 1           3                122  alfa-romero        std          two
# 2           1                122  alfa-romero        std          two
# 3           2                164         audi        std         four
# 4           2                164         audi        std         four
# 5           2                122         audi        std          two
# 6           1                158         audi        std         four
# 7           1                122         audi        std         four
# 8           1                158         audi      turbo         four
# 9           2                192          bmw        std          two
# 10          0                192          bmw        std         four
# 11          0                188          bmw        std          two
# 12          0                188          bmw        std         four
# 13          1                122          bmw        std         four
# 14          0                122          bmw        std         four
# 15          0                122          bmw        std          two
# 16          0                122          bmw        std         four
# 17          2                121    chevrolet        std          two
# 18          1                 98    chevrolet        std          two
# 19          0                 81    chevrolet        std         four
# 20          1                118        dodge        std          two
# 21          1                118        dodge        std          two
# 22          1                118        dodge      turbo          two
# 23          1                148        dodge        std         four
# 24          1                148        dodge        std         four
# 25          1                148        dodge        std         four
# 26          1                148        dodge      turbo         four
# 27         -1                110        dodge        std         four
# 28          3                145        dodge      turbo          two
# 29          2                137        honda        std          two
# 30          2                137        honda        std          two
# 31          1                101        honda        std          two
# 32          1                101        honda        std          two
# 33          1                101        honda        std          two
# 34          0                110        honda        std         four
# 35          0                 78        honda        std         four
# 36          0                106        honda        std          two
# 37          0                106        honda        std          two
# 38          0                 85        honda        std         four
# 39          0                 85        honda        std         four
# 40          0                 85        honda        std         four
# 41          1                107        honda        std          two
# 42          0                122        isuzu        std         four
# 43          2                122        isuzu        std          two
# 44          0                145       jaguar        std         four
# 45          0                122       jaguar        std         four
# 46          0                122       jaguar        std          two
# 47          1                104        mazda        std          two
# 48          1                104        mazda        std          two
# 49          1                104        mazda        std          two
#
#      body-style drive-wheels engine-location  wheel-base    length     width  \
# 0   convertible          rwd           front        88.6  0.811148  0.890278
# 1   convertible          rwd           front        88.6  0.811148  0.890278
# 2     hatchback          rwd           front        94.5  0.822681  0.909722
# 3         sedan          fwd           front        99.8  0.848630  0.919444
# 4         sedan          4wd           front        99.4  0.848630  0.922222
# 5         sedan          fwd           front        99.8  0.851994  0.920833
# 6         sedan          fwd           front       105.8  0.925997  0.991667
# 7         wagon          fwd           front       105.8  0.925997  0.991667
# 8         sedan          fwd           front       105.8  0.925997  0.991667
# 9         sedan          rwd           front       101.2  0.849592  0.900000
# 10        sedan          rwd           front       101.2  0.849592  0.900000
# 11        sedan          rwd           front       101.2  0.849592  0.900000
# 12        sedan          rwd           front       101.2  0.849592  0.900000
# 13        sedan          rwd           front       103.5  0.908217  0.929167
# 14        sedan          rwd           front       103.5  0.908217  0.929167
# 15        sedan          rwd           front       103.5  0.931283  0.943056
# 16        sedan          rwd           front       110.0  0.946660  0.984722
# 17    hatchback          fwd           front        88.4  0.678039  0.837500
# 18    hatchback          fwd           front        94.5  0.749159  0.883333
# 19        sedan          fwd           front        94.5  0.763095  0.883333
# 20    hatchback          fwd           front        93.7  0.755887  0.886111
# 21    hatchback          fwd           front        93.7  0.755887  0.886111
# 22    hatchback          fwd           front        93.7  0.755887  0.886111
# 23    hatchback          fwd           front        93.7  0.755887  0.886111
# 24        sedan          fwd           front        93.7  0.755887  0.886111
# 25        sedan          fwd           front        93.7  0.755887  0.886111
# 26        sedan          fwd           front        93.7  0.755887  0.886111
# 27        wagon          fwd           front       103.3  0.839020  0.897222
# 28    hatchback          fwd           front        95.9  0.832292  0.920833
# 29    hatchback          fwd           front        86.6  0.694858  0.887500
# 30    hatchback          fwd           front        86.6  0.694858  0.887500
# 31    hatchback          fwd           front        93.7  0.720807  0.888889
# 32    hatchback          fwd           front        93.7  0.720807  0.888889
# 33    hatchback          fwd           front        93.7  0.720807  0.888889
# 34        sedan          fwd           front        96.5  0.785199  0.888889
# 35        wagon          fwd           front        96.5  0.754926  0.887500
# 36    hatchback          fwd           front        96.5  0.804901  0.905556
# 37    hatchback          fwd           front        96.5  0.804901  0.905556
# 38        sedan          fwd           front        96.5  0.842864  0.905556
# 39        sedan          fwd           front        96.5  0.842864  0.868056
# 40        sedan          fwd           front        96.5  0.842864  0.905556
# 41        sedan          fwd           front        96.5  0.812590  0.916667
# 42        sedan          rwd           front        94.3  0.820279  0.858333
# 43    hatchback          rwd           front        96.0  0.829409  0.905556
# 44        sedan          rwd           front       113.0  0.959154  0.966667
# 45        sedan          rwd           front       113.0  0.959154  0.966667
# 46        sedan          rwd           front       102.0  0.921192  0.980556
# 47    hatchback          fwd           front        93.1  0.764536  0.891667
# 48    hatchback          fwd           front        93.1  0.764536  0.891667
# 49    hatchback          fwd           front        93.1  0.764536  0.891667
#
#     height  curb-weight engine-type num-of-cylinders  engine-size fuel-system  \
# 0     48.8         2548        dohc             four          130        mpfi
# 1     48.8         2548        dohc             four          130        mpfi
# 2     52.4         2823        ohcv              six          152        mpfi
# 3     54.3         2337         ohc             four          109        mpfi
# 4     54.3         2824         ohc             five          136        mpfi
# 5     53.1         2507         ohc             five          136        mpfi
# 6     55.7         2844         ohc             five          136        mpfi
# 7     55.7         2954         ohc             five          136        mpfi
# 8     55.9         3086         ohc             five          131        mpfi
# 9     54.3         2395         ohc             four          108        mpfi
# 10    54.3         2395         ohc             four          108        mpfi
# 11    54.3         2710         ohc              six          164        mpfi
# 12    54.3         2765         ohc              six          164        mpfi
# 13    55.7         3055         ohc              six          164        mpfi
# 14    55.7         3230         ohc              six          209        mpfi
# 15    53.7         3380         ohc              six          209        mpfi
# 16    56.3         3505         ohc              six          209        mpfi
# 17    53.2         1488           l            three           61        2bbl
# 18    52.0         1874         ohc             four           90        2bbl
# 19    52.0         1909         ohc             four           90        2bbl
# 20    50.8         1876         ohc             four           90        2bbl
# 21    50.8         1876         ohc             four           90        2bbl
# 22    50.8         2128         ohc             four           98        mpfi
# 23    50.6         1967         ohc             four           90        2bbl
# 24    50.6         1989         ohc             four           90        2bbl
# 25    50.6         1989         ohc             four           90        2bbl
# 26    50.6         2191         ohc             four           98        mpfi
# 27    59.8         2535         ohc             four          122        2bbl
# 28    50.2         2811         ohc             four          156         mfi
# 29    50.8         1713         ohc             four           92        1bbl
# 30    50.8         1819         ohc             four           92        1bbl
# 31    52.6         1837         ohc             four           79        1bbl
# 32    52.6         1940         ohc             four           92        1bbl
# 33    52.6         1956         ohc             four           92        1bbl
# 34    54.5         2010         ohc             four           92        1bbl
# 35    58.3         2024         ohc             four           92        1bbl
# 36    53.3         2236         ohc             four          110        1bbl
# 37    53.3         2289         ohc             four          110        1bbl
# 38    54.1         2304         ohc             four          110        1bbl
# 39    54.1         2372         ohc             four          110        1bbl
# 40    54.1         2465         ohc             four          110        mpfi
# 41    51.0         2293         ohc             four          110        2bbl
# 42    53.5         2337         ohc             four          111        2bbl
# 43    51.4         2734         ohc             four          119        spfi
# 44    52.8         4066        dohc              six          258        mpfi
# 45    52.8         4066        dohc              six          258        mpfi
# 46    47.8         3950        ohcv           twelve          326        mpfi
# 47    54.1         1890         ohc             four           91        2bbl
# 48    54.1         1900         ohc             four           91        2bbl
# 49    54.1         1905         ohc             four           91        2bbl
#
#     bore  stroke  compression-ratio  horsepower  peak-rpm  city-mpg  \
# 0   3.47    2.68               9.00       111.0    5000.0        21
# 1   3.47    2.68               9.00       111.0    5000.0        21
# 2   2.68    3.47               9.00       154.0    5000.0        19
# 3   3.19    3.40              10.00       102.0    5500.0        24
# 4   3.19    3.40               8.00       115.0    5500.0        18
# 5   3.19    3.40               8.50       110.0    5500.0        19
# 6   3.19    3.40               8.50       110.0    5500.0        19
# 7   3.19    3.40               8.50       110.0    5500.0        19
# 8   3.13    3.40               8.30       140.0    5500.0        17
# 9   3.50    2.80               8.80       101.0    5800.0        23
# 10  3.50    2.80               8.80       101.0    5800.0        23
# 11  3.31    3.19               9.00       121.0    4250.0        21
# 12  3.31    3.19               9.00       121.0    4250.0        21
# 13  3.31    3.19               9.00       121.0    4250.0        20
# 14  3.62    3.39               8.00       182.0    5400.0        16
# 15  3.62    3.39               8.00       182.0    5400.0        16
# 16  3.62    3.39               8.00       182.0    5400.0        15
# 17  2.91    3.03               9.50        48.0    5100.0        47
# 18  3.03    3.11               9.60        70.0    5400.0        38
# 19  3.03    3.11               9.60        70.0    5400.0        38
# 20  2.97    3.23               9.41        68.0    5500.0        37
# 21  2.97    3.23               9.40        68.0    5500.0        31
# 22  3.03    3.39               7.60       102.0    5500.0        24
# 23  2.97    3.23               9.40        68.0    5500.0        31
# 24  2.97    3.23               9.40        68.0    5500.0        31
# 25  2.97    3.23               9.40        68.0    5500.0        31
# 26  3.03    3.39               7.60       102.0    5500.0        24
# 27  3.34    3.46               8.50        88.0    5000.0        24
# 28  3.60    3.90               7.00       145.0    5000.0        19
# 29  2.91    3.41               9.60        58.0    4800.0        49
# 30  2.91    3.41               9.20        76.0    6000.0        31
# 31  2.91    3.07              10.10        60.0    5500.0        38
# 32  2.91    3.41               9.20        76.0    6000.0        30
# 33  2.91    3.41               9.20        76.0    6000.0        30
# 34  2.91    3.41               9.20        76.0    6000.0        30
# 35  2.92    3.41               9.20        76.0    6000.0        30
# 36  3.15    3.58               9.00        86.0    5800.0        27
# 37  3.15    3.58               9.00        86.0    5800.0        27
# 38  3.15    3.58               9.00        86.0    5800.0        27
# 39  3.15    3.58               9.00        86.0    5800.0        27
# 40  3.15    3.58               9.00       101.0    5800.0        24
# 41  3.15    3.58               9.10       100.0    5500.0        25
# 42  3.31    3.23               8.50        78.0    4800.0        24
# 43  3.43    3.23               9.20        90.0    5000.0        24
# 44  3.63    4.17               8.10       176.0    4750.0        15
# 45  3.63    4.17               8.10       176.0    4750.0        15
# 46  3.54    2.76              11.50       262.0    5000.0        13
# 47  3.03    3.15               9.00        68.0    5000.0        30
# 48  3.03    3.15               9.00        68.0    5000.0        31
# 49  3.03    3.15               9.00        68.0    5000.0        31
#
#     highway-mpg  price  city-L/100km horsepower-binned  diesel  gas
# 0            27  13495     11.190476            Medium       0    1
# 1            27  16500     11.190476            Medium       0    1
# 2            26  16500     12.368421            Medium       0    1
# 3            30  13950      9.791667            Medium       0    1
# 4            22  17450     13.055556            Medium       0    1
# 5            25  15250     12.368421            Medium       0    1
# 6            25  17710     12.368421            Medium       0    1
# 7            25  18920     12.368421            Medium       0    1
# 8            20  23875     13.823529            Medium       0    1
# 9            29  16430     10.217391               Low       0    1
# 10           29  16925     10.217391               Low       0    1
# 11           28  20970     11.190476            Medium       0    1
# 12           28  21105     11.190476            Medium       0    1
# 13           25  24565     11.750000            Medium       0    1
# 14           22  30760     14.687500              High       0    1
# 15           22  41315     14.687500              High       0    1
# 16           20  36880     15.666667              High       0    1
# 17           53   5151      5.000000               Low       0    1
# 18           43   6295      6.184211               Low       0    1
# 19           43   6575      6.184211               Low       0    1
# 20           41   5572      6.351351               Low       0    1
# 21           38   6377      7.580645               Low       0    1
# 22           30   7957      9.791667            Medium       0    1
# 23           38   6229      7.580645               Low       0    1
# 24           38   6692      7.580645               Low       0    1
# 25           38   7609      7.580645               Low       0    1
# 26           30   8558      9.791667            Medium       0    1
# 27           30   8921      9.791667               Low       0    1
# 28           24  12964     12.368421            Medium       0    1
# 29           54   6479      4.795918               Low       0    1
# 30           38   6855      7.580645               Low       0    1
# 31           42   5399      6.184211               Low       0    1
# 32           34   6529      7.833333               Low       0    1
# 33           34   7129      7.833333               Low       0    1
# 34           34   7295      7.833333               Low       0    1
# 35           34   7295      7.833333               Low       0    1
# 36           33   7895      8.703704               Low       0    1
# 37           33   9095      8.703704               Low       0    1
# 38           33   8845      8.703704               Low       0    1
# 39           33  10295      8.703704               Low       0    1
# 40           28  12945      9.791667               Low       0    1
# 41           31  10345      9.400000               Low       0    1
# 42           29   6785      9.791667               Low       0    1
# 43           29  11048      9.791667               Low       0    1
# 44           19  32250     15.666667              High       0    1
# 45           19  35550     15.666667              High       0    1
# 46           17  36000     18.076923               NaN       0    1
# 47           31   5195      7.833333               Low       0    1
# 48           38   6095      7.580645               Low       0    1
# 49           38   6795      7.580645               Low       0    1

# %% [markdown]
# ### Section 1: Heat map

# %%
plt.figure(figsize=(15,10))
plt.title('Correlation', fontsize=16)
cor = df.corr()
sns.heatmap(cor, annot=True);

# %%
# Write code here
df.describe(include='object')
# Out:
#           make aspiration num-of-doors body-style drive-wheels  \
# count      201        201          201        201          201
# unique      22          2            2          5            3
# top     toyota        std         four      sedan          fwd
# freq        32        165          115         94          118
#
#        engine-location engine-type num-of-cylinders fuel-system  \
# count              201         201              201         201
# unique               2           6                7           8
# top              front         ohc             four        mpfi
# freq               198         145              157          92
#
#        horsepower-binned
# count                200
# unique                 3
# top                  Low
# freq                 115

# %% [markdown]
# # Machine Learning

# %% [markdown]
# Loading data

# %%
data_c = pd.read_csv('classification.csv')
df_c = data_c.copy()
df_c.head()
# Out:
#    IDENTITY_ID  TARGET_FLAG  OB_VC_Actv_Days  IB_VC_Actv_Days  GPRS_Actv_Days  \
# 0          100            1               26               30               0
# 1          101            0               30               26              16
# 2          102            0               30               29               3
# 3          103            0               22               26              26
# 4          104            0                4               10               1
#
#    OB_SMS_Actv_Days  IB_SMS_Actv_Days  RECH_Actv_Days  RECH_AMT  GPRS_REV  \
# 0                29                30              10     600.0     0.000
# 1                30                30               6     620.0    31.555
# 2                30                30               9     600.0    20.259
# 3                 0                 5              12     670.0   179.747
# 4                 0                 1               2      80.0     0.000
#
#    GPRS_SUB_REV  GPRS_FLAG  RECH_FLAG  GPRS_VOL_MB  Tech_Awareness  \
# 0           0.0          0          1          0.0               0
# 1          24.0          1          1       1310.6               1
# 2           0.0          1          1         92.5               0
# 3         120.0          1          1       3291.3               1
# 4           0.0          1          1          0.1               0
#
#    NW Experience  Sites_Perc  Target_SUB_Perc  Target_Conv_Perc
# 0           0.92        0.71           0.0611            0.0075
# 1           0.96        0.12           0.0130            0.0163
# 2           0.96        0.96           0.0809            0.0286
# 3           0.98        0.12           0.0004            0.0720
# 4           0.99        0.54           0.0483            0.0178

# %%
df_c.shape
# Out:
# (20000, 19)

# %%
df = df_c.copy()

# %%
df.dtypes
# Out:
# IDENTITY_ID           int64
# TARGET_FLAG           int64
# OB_VC_Actv_Days       int64
# IB_VC_Actv_Days       int64
# GPRS_Actv_Days        int64
# OB_SMS_Actv_Days      int64
# IB_SMS_Actv_Days      int64
# RECH_Actv_Days        int64
# RECH_AMT            float64
# GPRS_REV            float64
# GPRS_SUB_REV        float64
# GPRS_FLAG             int64
# RECH_FLAG             int64
# GPRS_VOL_MB         float64
# Tech_Awareness        int64
# NW Experience       float64
# Sites_Perc          float64
# Target_SUB_Perc     float64
# Target_Conv_Perc    float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# IDENTITY_ID         0
# TARGET_FLAG         0
# OB_VC_Actv_Days     0
# IB_VC_Actv_Days     0
# GPRS_Actv_Days      0
# OB_SMS_Actv_Days    0
# IB_SMS_Actv_Days    0
# RECH_Actv_Days      0
# RECH_AMT            0
# GPRS_REV            0
# GPRS_SUB_REV        0
# GPRS_FLAG           0
# RECH_FLAG           0
# GPRS_VOL_MB         0
# Tech_Awareness      0
# NW Experience       0
# Sites_Perc          0
# Target_SUB_Perc     0
# Target_Conv_Perc    0
# dtype: int64

# %%
list(df.columns)
# Out:
# ['IDENTITY_ID',
#  'TARGET_FLAG',
#  'OB_VC_Actv_Days',
#  'IB_VC_Actv_Days',
#  'GPRS_Actv_Days',
#  'OB_SMS_Actv_Days',
#  'IB_SMS_Actv_Days',
#  'RECH_Actv_Days',
#  'RECH_AMT',
#  'GPRS_REV',
#  'GPRS_SUB_REV',
#  'GPRS_FLAG',
#  'RECH_FLAG',
#  'GPRS_VOL_MB',
#  'Tech_Awareness',
#  'NW Experience',
#  'Sites_Perc',
#  'Target_SUB_Perc',
#  'Target_Conv_Perc']

# %% [markdown]
# ## Section 1: Decision Tree

# %% [markdown]
# Please make sure to complete the following tasks in order.
# 1. Create dependent and independent variables
# 2. Split data into train and test with test size of 20% and random state = 25
# 3. Import decision tree classifier and train it with default settings and random state = 25
# 4. Get predictions on the trained model
# 5. Get classification report for the model

# %% [markdown]
# **Task 1: Creating dependent and independent variables**

# %% [markdown]
# *Note: Target_Flag is dependent variable*

# %%
df.head()
# Out:
#    IDENTITY_ID  TARGET_FLAG  OB_VC_Actv_Days  IB_VC_Actv_Days  GPRS_Actv_Days  \
# 0          100            1               26               30               0
# 1          101            0               30               26              16
# 2          102            0               30               29               3
# 3          103            0               22               26              26
# 4          104            0                4               10               1
#
#    OB_SMS_Actv_Days  IB_SMS_Actv_Days  RECH_Actv_Days  RECH_AMT  GPRS_REV  \
# 0                29                30              10    600.00      0.00
# 1                30                30               6    620.00     31.55
# 2                30                30               9    600.00     20.26
# 3                 0                 5              12    670.00    179.75
# 4                 0                 1               2     80.00      0.00
#
#    GPRS_SUB_REV  GPRS_FLAG  RECH_FLAG  GPRS_VOL_MB  Tech_Awareness  \
# 0          0.00          0          1         0.00               0
# 1         24.00          1          1      1310.60               1
# 2          0.00          1          1        92.50               0
# 3        120.00          1          1      3291.30               1
# 4          0.00          1          1         0.10               0
#
#    NW Experience  Sites_Perc  Target_SUB_Perc  Target_Conv_Perc
# 0           0.92        0.71             0.06              0.01
# 1           0.96        0.12             0.01              0.02
# 2           0.96        0.96             0.08              0.03
# 3           0.98        0.12             0.00              0.07
# 4           0.99        0.54             0.05              0.02

# %%
# write code here
df['TARGET_FLAG']

X = df.drop(['TARGET_FLAG'], axis=1)
Y = df['TARGET_FLAG']

# %% [markdown]
# **Task 2: Splitting data into train and test with test size of 20% and random state = 25**

# %%
from sklearn.model_selection import train_test_split
# Write the code below to split the data
X_train,X_test,Y_train,Y_test = train_test_split(X, Y, test_size=0.20, random_state=25,shuffle=True)

# %%
# Print the shapes of above split data
print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)
# Out:
# (16000, 18) (16000,)
# (4000, 18) (4000,)

# %%
Y_test.value_counts()
# Out:
# 0    2041
# 1    1959
# Name: TARGET_FLAG, dtype: int64

# %% [markdown]
# **Task 3: Importing decision tree classifier and training it with default settings and random state = 25**

# %%
# Write the code to import decision tree from sklearn
from sklearn import tree
model = tree.DecisionTreeClassifier(random_state = 25)

# %%
# Train the model
model.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(random_state=25)

# %% [markdown]
# **Task 4: Get predictions**

# %%
# Write the code to get predictions
tree_pr = model.predict(X_test)

# %% [markdown]
# **Task 5: Get Classification report**

# %%
# Write the code here
from sklearn.metrics import classification_report
print(classification_report(Y_test, tree_pr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.69      0.70      2041
#            1       0.69      0.71      0.70      1959
#
#     accuracy                           0.70      4000
#    macro avg       0.70      0.70      0.70      4000
# weighted avg       0.70      0.70      0.70      4000

# %% [markdown]
# ## Section 2: Random Forest

# %% [markdown]
# Perform the following tasks in order
# 1. Import random forest classifier and train it with default settings and random state = 25
# 2. Get predictions on the trained model
# 3. Get classification report for the model

# %% [markdown]
# **Task 1:Importing random forest classifier and training it with default settings and random state = 25**

# %%
# Write the code to import random forest from sklearn
from sklearn.ensemble import RandomForestClassifier

# %%
# Train the model
rf = RandomForestClassifier(random_state = 25)
rf.fit(X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [114], in <cell line: 3>()
#       1 # Train the model
#       2 rf = RandomForestClassifier(random_state = 25)
# ----> 3 rf.fit(X_train, Y_train)
#
# NameError: name 'X_train' is not defined

# %% [markdown]
# **Task 2: Write the code to get predictions**

# %%
# Write the code here
rf_pred=rf.predict(X_test)

# %% [markdown]
# **Task 3: Get classification report**

# %%
# Write the code here
print(classification_report(Y_test, rf_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [111], in <cell line: 2>()
#       1 # Write the code here
# ----> 2 print(classification_report(Y_test, rf_pred))
#
# NameError: name 'classification_report' is not defined
